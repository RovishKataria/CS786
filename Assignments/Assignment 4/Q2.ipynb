# %% [markdown]
# # Q2. (40 points)
# I am also sharing with you, John McDonnell's python implementation of Anderson's Rational Model of Categorization (rational.py).
# Modify the code to obtain category predictions for the data I have shared with you.

# %%
import numpy as np
import pandas as pd
from scipy.stats import norm

# %%
X = pd.read_csv('X.csv', header=None).values
y_test = pd.read_csv('y.csv', header=None).values

# Separate data into weight, height, and labels
weights = X[:, 0]
heights = X[:, 1]

# Categories: 1 = small, 2 = average, 3 = large
labels = X[:, 2]

# Split data by category
small = X[labels == 1]
average = X[labels == 2]
large = X[labels == 3]

# %%
# Calculating mean and standard deviation of weight and height for each category.
params = {
    'small': {
        'weight_mean': np.mean(small[:, 0]),
        'weight_std': np.std(small[:, 0]),
        'height_mean': np.mean(small[:, 1]),
        'height_std': np.std(small[:, 1])
    },
    'average': {
        'weight_mean': np.mean(average[:, 0]),
        'weight_std': np.std(average[:, 0]),
        'height_mean': np.mean(average[:, 1]),
        'height_std': np.std(average[:, 1])
    },
    'large': {
        'weight_mean': np.mean(large[:, 0]),
        'weight_std': np.std(large[:, 0]),
        'height_mean': np.mean(large[:, 1]),
        'height_std': np.std(large[:, 1])
    }
}

# %% [markdown]
# # Incorporating posterior formula:
# # P(cN=j|xN,xN-1,cN-1) = [p(xN|cN=j,xN-1,cN-1) . p(cN=j|cN-1)] / ∑c[p(xN|cN=j,xN-1,cN-1) . p(cN=j|cN-1)]

# %%
def likelihood(weight, height, category, params):
    # Calculating likelihood for weight and height
    weight_likelihood = norm.pdf(weight, params[category]['weight_mean'], params[category]['weight_std'])
    height_likelihood = norm.pdf(height, params[category]['height_mean'], params[category]['height_std'])
    
    # Adjusting likelihood based on weight's higher importance
    likelihood = (weight_likelihood ** 0.7) * (height_likelihood ** 0.3)
    return likelihood

def posterior_prob(weight, height, params):
    # Calculating posterior probability for each category
    posterior_probs = {}
    categories = ['small', 'average', 'large']
    cat_labels = {category: i + 1 for i, category in enumerate(categories)}
    
    for category in categories:
        cat_label = cat_labels[category]
        posterior_probs[cat_label] = likelihood(weight, height, category, params)
    
    # Normalizing the probabilities so that they sum to 1
    total_posterior = sum(posterior_probs.values())
    for cat_label in posterior_probs:
        posterior_probs[cat_label] /= total_posterior
    
    return posterior_probs

def predict_cat_label(posterior_probs):
    # Returning the category with the highest posterior probability
    return max(posterior_probs, key=posterior_probs.get)

# %%
def evaluate_model(X, labels, params):
    # Predict labels for X.csv and compare with given labels
    predictions = []
    accuracy = 0
    
    for i in range(len(X)):
        weight, height = X[i, 0], X[i, 1]
        true_label = X[i, 2]
        
        # Calculate posterior probabilities for this instance 
        posterior_probs = posterior_prob(weight, height, params)
        
        # Find the category with the highest posterior probability
        predicted_label = predict_cat_label(posterior_probs)
        
        # Append the prediction
        predictions.append(predicted_label)
        
        print(f"Sample {i + 1}\nTrue label = {true_label}, Predicted label = {predicted_label}, Posterior probs = {posterior_probs}\n")
        
        # Check if prediction matches true label
        if predicted_label == true_label:
            accuracy += 1
    
    accuracy /= len(labels)
    return predictions, accuracy

# %%
def predict_test_instances(y_test, params):
    # Predicting labels for y.csv
    y_predictions = []
    
    for i, test_instance in enumerate(y_test):
        weight, height = test_instance
        posterior_probs = posterior_prob(weight, height, params)
        
        # Finding the category with the highest posterior probability
        predicted_label = predict_cat_label(posterior_probs)
        
        y_predictions.append(predicted_label)
        print(f"Test instance {i + 1}\nWeight = {weight}, Height = {height}, Predicted label = {predicted_label}\n")
    
    return y_predictions

# %%
def main():
    predictions, accuracy = evaluate_model(X, labels, params)
    print(f"Accuracy on X.csv: {accuracy * 100:.2f}%")
    
    if accuracy == 1.0:
        print("\nPredictions for y.csv:")
        y_predictions = predict_test_instances(y_test, params)
        
        np.savetxt("Q2_Category_Label.csv", y_predictions, fmt="%d")
        print("\nPredictions for y.csv saved to 'Q2_Category_Label.csv'")


if __name__ == "__main__":
    main()
# Out:
# Sample 1
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.999999231612128), 2: np.float64(7.683878719025623e-07), 3: np.float64(3.679673695252389e-25)}
#
# Sample 2
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9858333595201387), 2: np.float64(0.014166640479860796), 3: np.float64(5.208481360226441e-16)}
#
# Sample 3
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999996089783371), 2: np.float64(3.9102166292463367e-07), 3: np.float64(2.20744774981597e-25)}
#
# Sample 4
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999997800790268), 2: np.float64(2.1992097321665775e-07), 3: np.float64(1.5826099699707815e-27)}
#
# Sample 5
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999997039028208), 2: np.float64(2.9609717923512057e-07), 3: np.float64(1.8230766613548013e-26)}
#
# Sample 6
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999985306069831), 2: np.float64(1.469393016876117e-06), 3: np.float64(6.214086554578768e-25)}
#
# Sample 7
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999997238928408), 2: np.float64(2.761071591929956e-07), 3: np.float64(1.7181039387774786e-25)}
#
# Sample 8
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999669816652759), 2: np.float64(3.301833472409091e-05), 3: np.float64(5.7814829888738765e-21)}
#
# Sample 9
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9999861354893658), 2: np.float64(1.3864510634181614e-05), 3: np.float64(3.7354500516696994e-23)}
#
# Sample 10
# True label = 1, Predicted label = 1, Posterior probs = {1: np.float64(0.9983166357608803), 2: np.float64(0.0016833642391197545), 3: np.float64(1.4062070689275427e-18)}
#
# Sample 11
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.6563576006002913e-07), 2: np.float64(0.9999983665334461), 3: np.float64(1.2678307938754443e-06)}
#
# Sample 12
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(2.5306464111098837e-09), 2: np.float64(0.9998446096800725), 3: np.float64(0.0001553877892811673)}
#
# Sample 13
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(9.395111133993367e-13), 2: np.float64(0.9843826966770436), 3: np.float64(0.015617303322016812)}
#
# Sample 14
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(7.24386335033065e-13), 2: np.float64(0.9838610416588337), 3: np.float64(0.016138958340441902)}
#
# Sample 15
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(0.0005349226862528828), 2: np.float64(0.9994650757177564), 3: np.float64(1.5959907774342042e-09)}
#
# Sample 16
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.0271861137965291e-05), 2: np.float64(0.9999896790216884), 3: np.float64(4.911717355357814e-08)}
#
# Sample 17
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(2.1611765573451023e-07), 2: np.float64(0.9999984420667904), 3: np.float64(1.3418155537207372e-06)}
#
# Sample 18
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.1739731124489004e-12), 2: np.float64(0.9957855311098067), 3: np.float64(0.00421446888701924)}
#
# Sample 19
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(0.00019556498525243426), 2: np.float64(0.9998044265570724), 3: np.float64(8.457675201224462e-09)}
#
# Sample 20
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1356158379184107e-06), 2: np.float64(0.999997587322246), 3: np.float64(1.2770619161528741e-06)}
#
# Sample 21
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(5.157400083937893e-12), 2: np.float64(0.996249349404833), 3: np.float64(0.0037506505900096673)}
#
# Sample 22
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(4.9804354902105846e-08), 2: np.float64(0.9999935321233991), 3: np.float64(6.418072245922155e-06)}
#
# Sample 23
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1309911709962494e-08), 2: np.float64(0.9999687045579095), 3: np.float64(3.1284132178704384e-05)}
#
# Sample 24
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.3126648285732951e-07), 2: np.float64(0.9999983903210387), 3: np.float64(1.478412478455177e-06)}
#
# Sample 25
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(8.147959134315675e-10), 2: np.float64(0.9998457345486336), 3: np.float64(0.00015426463657044941)}
#
# Sample 26
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.511357819683954e-11), 2: np.float64(0.9991463548284937), 3: np.float64(0.0008536451363928511)}
#
# Sample 27
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(2.1611765573451023e-07), 2: np.float64(0.9999984420667904), 3: np.float64(1.3418155537207372e-06)}
#
# Sample 28
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.454461670231848e-13), 2: np.float64(0.9811043038962031), 3: np.float64(0.018895696103451445)}
#
# Sample 29
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(4.816000061090997e-10), 2: np.float64(0.9998367341908888), 3: np.float64(0.00016326532751109523)}
#
# Sample 30
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1817483210847167e-06), 2: np.float64(0.9999985472574698), 3: np.float64(2.7099420904861926e-07)}
#
# Sample 31
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.0706862538603655e-09), 2: np.float64(0.9998477678716192), 3: np.float64(0.0001522310576946197)}
#
# Sample 32
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.3825244829636104e-06), 2: np.float64(0.9999963755419763), 3: np.float64(2.419335407007909e-07)}
#
# Sample 33
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1159821941174432e-08), 2: np.float64(0.9999914043968423), 3: np.float64(8.584443335712218e-06)}
#
# Sample 34
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(8.147959134315675e-10), 2: np.float64(0.9998457345486336), 3: np.float64(0.00015426463657044941)}
#
# Sample 35
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.3315248747219625e-05), 2: np.float64(0.9999866372470118), 3: np.float64(4.7504241046870456e-08)}
#
# Sample 36
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1356158379184107e-06), 2: np.float64(0.999997587322246), 3: np.float64(1.2770619161528741e-06)}
#
# Sample 37
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(7.978186559819382e-06), 2: np.float64(0.9999919705152721), 3: np.float64(5.129816815080576e-08)}
#
# Sample 38
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.972295900980998e-06), 2: np.float64(0.9999977767510255), 3: np.float64(2.509530736087295e-07)}
#
# Sample 39
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(5.7815690850072856e-11), 2: np.float64(0.9992251657003257), 3: np.float64(0.0007748342418585437)}
#
# Sample 40
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(0.00011249848115317329), 2: np.float64(0.9998874929198607), 3: np.float64(8.598986148560932e-09)}
#
# Sample 41
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(4.4751592481436326e-06), 2: np.float64(0.9999952836839919), 3: np.float64(2.411567599752241e-07)}
#
# Sample 42
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.1159821941174432e-08), 2: np.float64(0.9999914043968423), 3: np.float64(8.584443335712218e-06)}
#
# Sample 43
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(8.619877587947546e-05), 2: np.float64(0.9999137924219352), 3: np.float64(8.80218521636158e-09)}
#
# Sample 44
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(2.7283222752159038e-08), 2: np.float64(0.9999670616553531), 3: np.float64(3.291106142414229e-05)}
#
# Sample 45
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(0.002452121210781687), 2: np.float64(0.9975478784967519), 3: np.float64(2.9246643421824863e-10)}
#
# Sample 46
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(8.548524336113973e-09), 2: np.float64(0.9999686065885299), 3: np.float64(3.138486294577491e-05)}
#
# Sample 47
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(4.984494953743937e-09), 2: np.float64(0.9999674401759611), 3: np.float64(3.2554839543953536e-05)}
#
# Sample 48
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.1801819629661264e-05), 2: np.float64(0.9999681874942572), 3: np.float64(1.0686113145870032e-08)}
#
# Sample 49
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(3.6563576006002913e-07), 2: np.float64(0.9999983665334461), 3: np.float64(1.2678307938754443e-06)}
#
# Sample 50
# True label = 2, Predicted label = 2, Posterior probs = {1: np.float64(1.82564822375178e-10), 2: np.float64(0.9997936746397413), 3: np.float64(0.00020632517769380202)}
#
# Sample 51
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(1.0962178916374005e-29), 2: np.float64(1.3031632110474387e-05), 3: np.float64(0.9999869683678895)}
#
# Sample 52
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(5.089588335908676e-23), 2: np.float64(0.0023280046237244435), 3: np.float64(0.9976719953762755)}
#
# Sample 53
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(3.0437851796557406e-36), 2: np.float64(1.0941863690378349e-07), 3: np.float64(0.9999998905813631)}
#
# Sample 54
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(3.770276873873601e-31), 2: np.float64(4.0746865031568e-06), 3: np.float64(0.9999959253134969)}
#
# Sample 55
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(2.0784242975361063e-31), 2: np.float64(3.6982097903096513e-06), 3: np.float64(0.9999963017902097)}
#
# Sample 56
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(1.3021143103323153e-21), 2: np.float64(0.007755166796217944), 3: np.float64(0.992244833203782)}
#
# Sample 57
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(2.8038829378243824e-31), 2: np.float64(3.901456614418198e-06), 3: np.float64(0.9999960985433857)}
#
# Sample 58
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(1.5785401202197922e-30), 2: np.float64(4.354257142090076e-06), 3: np.float64(0.9999956457428578)}
#
# Sample 59
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(5.089588335908676e-23), 2: np.float64(0.0023280046237244435), 3: np.float64(0.9976719953762755)}
#
# Sample 60
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(6.750921885661536e-31), 2: np.float64(4.312465070143389e-06), 3: np.float64(0.9999956875349298)}
#
# Sample 61
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(5.964982303731243e-30), 2: np.float64(1.1361230968427095e-05), 3: np.float64(0.9999886387690315)}
#
# Sample 62
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(1.9885453819441e-29), 2: np.float64(1.43582349388092e-05), 3: np.float64(0.9999856417650611)}
#
# Sample 63
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(8.302012455970671e-32), 2: np.float64(2.9653700234394045e-06), 3: np.float64(0.9999970346299766)}
#
# Sample 64
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(1.0496360652894994e-24), 2: np.float64(0.0006077163817916003), 3: np.float64(0.9993922836182083)}
#
# Sample 65
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(4.3869644652447716e-21), 2: np.float64(0.010178353713801276), 3: np.float64(0.9898216462861986)}
#
# Sample 66
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(4.613621089292018e-24), 2: np.float64(0.0007550476944820593), 3: np.float64(0.999244952305518)}
#
# Sample 67
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(7.899976861714762e-21), 2: np.float64(0.01098226272847543), 3: np.float64(0.9890177372715245)}
#
# Sample 68
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(2.1769003505128916e-25), 2: np.float64(0.00020306102169647503), 3: np.float64(0.9997969389783035)}
#
# Sample 69
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(2.081590106948572e-30), 2: np.float64(4.281289618311388e-06), 3: np.float64(0.9999957187103817)}
#
# Sample 70
# True label = 3, Predicted label = 3, Posterior probs = {1: np.float64(3.2514067065802686e-27), 2: np.float64(5.56084852377076e-05), 3: np.float64(0.9999443915147622)}
#
# Accuracy on X.csv: 100.00%
#
# Predictions for y.csv:
# Test instance 1
# Weight = 74, Height = 67, Predicted label = 3
#
# Test instance 2
# Weight = 69, Height = 63, Predicted label = 2
#
# Test instance 3
# Weight = 92, Height = 81, Predicted label = 3
#
# Test instance 4
# Weight = 64, Height = 61, Predicted label = 2
#
# Test instance 5
# Weight = 66, Height = 84, Predicted label = 2
#
# Test instance 6
# Weight = 76, Height = 68, Predicted label = 3
#
# Test instance 7
# Weight = 61, Height = 58, Predicted label = 2
#
# Test instance 8
# Weight = 64, Height = 76, Predicted label = 2
#
# Test instance 9
# Weight = 68, Height = 66, Predicted label = 2
#
# Test instance 10
# Weight = 34, Height = 61, Predicted label = 1
#
#
# Predictions for y.csv saved to 'Q2_Category_Label.csv'
